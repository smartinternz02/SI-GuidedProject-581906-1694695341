# %%
import pandas as pd
import numpy as np

# %%
d={'Name':['Aaron','Buffy','Cam','Dee','Emma','Frank'],'Age':[19,20,22,17,18,21],'Gender':['M','F','M','F','F','M']}
df=pd.DataFrame(d)
df
# Out:
#     Name  Age Gender
# 0  Aaron   19      M
# 1  Buffy   20      F
# 2    Cam   22      M
# 3    Dee   17      F
# 4   Emma   18      F
# 5  Frank   21      M

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 6 entries, 0 to 5
# Data columns (total 3 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   Name    6 non-null      object
#  1   Age     6 non-null      int64
#  2   Gender  6 non-null      object
# dtypes: int64(1), object(2)
# memory usage: 272.0+ bytes

# %%
df.describe()
# Out:
#              Age
# count   6.000000
# mean   19.500000
# std     1.870829
# min    17.000000
# 25%    18.250000
# 50%    19.500000
# 75%    20.750000
# max    22.000000

# %%
df.loc[4]
# Out:
# Name      Emma
# Age         18
# Gender       F
# Name: 4, dtype: object

# %%
df.isnull().any()
# Out:
# Name      False
# Age       False
# Gender    False
# dtype: bool

# %%
df.isnull().sum()
# Out:
# Name      0
# Age       0
# Gender    0
# dtype: int64
