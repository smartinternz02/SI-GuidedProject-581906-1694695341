# %%
import numpy as np
import pandas as pd

# %%
df=pd.read_csv('/content/winequality-red.csv')
df.head()
# Out:
#    fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0            7.4              0.70         0.00             1.9      0.076
# 1            7.8              0.88         0.00             2.6      0.098
# 2            7.8              0.76         0.04             2.3      0.092
# 3           11.2              0.28         0.56             1.9      0.075
# 4            7.4              0.70         0.00             1.9      0.076
#
#    free sulfur dioxide  total sulfur dioxide  density    pH  sulphates  \
# 0                 11.0                  34.0   0.9978  3.51       0.56
# 1                 25.0                  67.0   0.9968  3.20       0.68
# 2                 15.0                  54.0   0.9970  3.26       0.65
# 3                 17.0                  60.0   0.9980  3.16       0.58
# 4                 11.0                  34.0   0.9978  3.51       0.56
#
#    alcohol  quality
# 0      9.4        5
# 1      9.8        5
# 2      9.8        5
# ...

# %%
import matplotlib.pyplot as plt

# %%
plt.plot(df)

# %%
import seaborn as sns
sns.distplot(df)
# Out:
# <ipython-input-7-619827088855>:2: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df)
# <Axes: ylabel='Density'>

# %%
df.corr()
# Out:
#                       fixed acidity  volatile acidity  citric acid  \
# fixed acidity              1.000000         -0.256131     0.671703
# volatile acidity          -0.256131          1.000000    -0.552496
# citric acid                0.671703         -0.552496     1.000000
# residual sugar             0.114777          0.001918     0.143577
# chlorides                  0.093705          0.061298     0.203823
# free sulfur dioxide       -0.153794         -0.010504    -0.060978
# total sulfur dioxide      -0.113181          0.076470     0.035533
# density                    0.668047          0.022026     0.364947
# pH                        -0.682978          0.234937    -0.541904
# sulphates                  0.183006         -0.260987     0.312770
# alcohol                   -0.061668         -0.202288     0.109903
# quality                    0.124052         -0.390558     0.226373
#
#                       residual sugar  chlorides  free sulfur dioxide  \
# ...

# %%
sns.heatmap(df.corr())
# Out:
# <Axes: >

# %%
df.isnull().any()
# Out:
# fixed acidity           False
# volatile acidity        False
# citric acid             False
# residual sugar          False
# chlorides               False
# free sulfur dioxide     False
# total sulfur dioxide    False
# density                 False
# pH                      False
# sulphates               False
# alcohol                 False
# quality                 False
# dtype: bool

# %%
df.head()
# Out:
#    fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0            7.4              0.70         0.00             1.9      0.076
# 1            7.8              0.88         0.00             2.6      0.098
# 2            7.8              0.76         0.04             2.3      0.092
# 3           11.2              0.28         0.56             1.9      0.075
# 4            7.4              0.70         0.00             1.9      0.076
#
#    free sulfur dioxide  total sulfur dioxide  density    pH  sulphates  \
# 0                 11.0                  34.0   0.9978  3.51       0.56
# 1                 25.0                  67.0   0.9968  3.20       0.68
# 2                 15.0                  54.0   0.9970  3.26       0.65
# 3                 17.0                  60.0   0.9980  3.16       0.58
# 4                 11.0                  34.0   0.9978  3.51       0.56
#
#    alcohol  quality
# 0      9.4        5
# 1      9.8        5
# 2      9.8        5
# ...

# %%
df.median()
# Out:
# fixed acidity            7.90000
# volatile acidity         0.52000
# citric acid              0.26000
# residual sugar           2.20000
# chlorides                0.07900
# free sulfur dioxide     14.00000
# total sulfur dioxide    38.00000
# density                  0.99675
# pH                       3.31000
# sulphates                0.62000
# alcohol                 10.20000
# quality                  6.00000
# dtype: float64

# %%
q1=df['fixed acidity'].quantile(0.25)
q3=df['fixed acidity'].quantile(0.75)

# %%
iqr=q3-q1

# %%
ul=q3+1.5*iqr
ll=q1-1.5*iqr

# %%
df['fixed acidity']=np.where(df['fixed acidity']>ul,7.9,df['fixed acidity'])

# %%
q1=df['volatile acidity'].quantile(0.25)
q3=df['volatile acidity'].quantile(0.75)

# %%
iqr=q3-q1

# %%
ul=q3+1.5*iqr
ll=q1-1.5*iqr

# %%
df['volatile acidity']=np.where(df['volatile acidity']>ul,0.52,df['volatile acidity'])

# %%
q1=df['citric acid'].quantile(0.25)
q3=df['citric acid'].quantile(0.75)

# %%
iqr=q3-q1

# %%
ul=q3+1.5*iqr
ll=q1-1.5*iqr

# %%
df['citric acid']=np.where(df['citric acid']>ul,0.26,df['citric acid'])

# %%
q1=df['residual sugar'].quantile(0.25)
q3=df['residual sugar'].quantile(0.75)

# %%
iqr=q3-q1

# %%
ul=q3+1.5*iqr
ll=q1-1.5*iqr

# %%
df['residual sugar']=np.where(df['residual sugar']>ul,2.20,df['residual sugar'])

# %%
q1=df['chlorides'].quantile(0.25)
q3=df['chlorides'].quantile(0.75)

# %%
iqr=q3-q1

# %%
ul=q3+1.5*iqr
ll=q1-1.5*iqr

# %%
df['chlorides']=np.where(df['chlorides']>ul,0.079,df['chlorides'])
df['chlorides']=np.where(df['chlorides']<ll,0.079,df['chlorides'])

# %%
q1=df['free sulfur dioxide'].quantile(0.25)
q3=df['free sulfur dioxide'].quantile(0.75)

# %%
iqr=q3-q1

# %%
ul=q3+1.5*iqr
ll=q1-1.5*iqr

# %%
df['free sulfur dioxide']=np.where(df['free sulfur dioxide']>ul,14,df['free sulfur dioxide'])

# %%
q1=df['total sulfur dioxide'].quantile(0.25)
q3=df['total sulfur dioxide'].quantile(0.75)

# %%
iqr=q3-q1

# %%
ul=q3+1.5*iqr
ll=q1-1.5*iqr

# %%
df['total sulfur dioxide']=np.where(df['total sulfur dioxide']>ul,38,df['total sulfur dioxide'])

# %%
q1=df['density'].quantile(0.25)
q3=df['density'].quantile(0.75)

# %%
iqr=q3-q1

# %%
ul=q3+1.5*iqr
ll=q1-1.5*iqr

# %%
df['density']=np.where(df['density']>ul,0.99675,df['density'])

# %%
q1=df['pH'].quantile(0.25)
q3=df['pH'].quantile(0.75)

# %%
iqr=q3-q1

# %%
ul=q3+1.5*iqr
ll=q1-1.5*iqr

# %%
df['pH']=np.where(df['pH']>ul,3.31,df['pH'])

# %%
q1=df['sulphates'].quantile(0.25)
q3=df['sulphates'].quantile(0.75)

# %%
iqr=q3-q1

# %%
ul=q3+1.5*iqr
ll=q1-1.5*iqr

# %%
df['sulphates']=np.where(df['pH']>ul,0.62,df['sulphates'])

# %%
q1=df['alcohol'].quantile(0.25)
q3=df['alcohol'].quantile(0.75)

# %%
iqr=q3-q1

# %%
ul=q3+1.5*iqr
ll=q1-1.5*iqr

# %%
df['alcohol']=np.where(df['pH']>ul,10.2,df['alcohol'])

# %%
q1=df['quality'].quantile(0.25)
q3=df['quality'].quantile(0.75)

# %%
iqr=q3-q1

# %%
ul=q3+1.5*iqr
ll=q1-1.5*iqr

# %%
df['quality']=np.where(df['pH']>ul,6,df['quality'])

# %%
from sklearn.model_selection import train_test_split

# %%
x=df.iloc[:,:-1]
y=df.quality

# %%
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.3,random_state=0)

# %%
from sklearn.linear_model import LinearRegression

# %%
model=LinearRegression()

# %%
model.fit(x_train,y_train)
# Out:
# LinearRegression()

# %%
ypred=model.predict(x_test)

# %%
from sklearn.metrics import accuracy_score,confusion_matrix,classification_report

# %%
pd.crosstab(y_test,ypred)
# Out:
# col_0    4.905531  4.926048  4.950401  4.957427  4.969208  4.978931  4.985031  \
# quality
# 3               0         0         0         0         0         0         0
# 4               1         0         0         0         1         0         0
# 5               0         1         1         1         0         1         0
# 6               0         0         0         0         0         0         1
# 7               0         0         0         0         0         0         0
# 8               0         0         0         0         0         0         0
#
# col_0    4.990952  5.001566  5.003478  ...  6.569490  6.580613  6.620410  \
# quality                                ...
# 3               0         0         0  ...         0         0         0
# 4               0         0         0  ...         0         0         0
# 5               1         1         0  ...         0         0         0
# 6               0         0         1  ...         0         1         0
# ...

# %%
df.head()
# Out:
#    fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0            7.4              0.52         0.26             2.2      0.079
# 1            7.8              0.52         0.26             2.2      0.079
# 2            7.8              0.52         0.26             2.2      0.079
# 3           11.2              0.52         0.26             2.2      0.079
# 4            7.4              0.52         0.26             2.2      0.079
#
#    free sulfur dioxide  total sulfur dioxide  density    pH  sulphates  \
# 0                 11.0                  38.0  0.99675  3.51       0.56
# 1                 25.0                  38.0  0.99675  3.20       0.68
# 2                 15.0                  38.0  0.99675  3.26       0.65
# 3                 17.0                  38.0  0.99675  3.16       0.58
# 4                 11.0                  38.0  0.99675  3.51       0.56
#
#    alcohol  quality
# 0      9.4        5
# 1      9.8        5
# 2      9.8        5
# ...

# %%
model.predict([[7.9,0.55,0.3,2.5,0.06,18.3,39.5,1.0,3.45,0.54,9.6]])
# Out:
# /usr/local/lib/python3.10/dist-packages/sklearn/base.py:439: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# array([5.18221128])
